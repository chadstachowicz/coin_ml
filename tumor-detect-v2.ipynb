# %% [markdown]
# Alright we are going to try and detect brain tumors. First we load pytorch, torchvision and some other libraries we need.

# %%
from transformers import AutoFeatureExtractor, ResNetForImageClassification
import torch
from torchvision import datasets,transforms
import torchvision
from torch.utils.tensorboard import SummaryWriter
from datetime import datetime
from torch.optim.lr_scheduler import StepLR
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import AutoFeatureExtractor, ResNetForImageClassification
#       2 import torch
#       3 from torchvision import datasets,transforms
#
# ModuleNotFoundError: No module named 'transformers'

# %% [markdown]
# Next we are going to load and transform our dataset. Here is what's important. I've resized and centered mine to 128x128. All you data and images need to be in the same size. You can do other things here like change the greyscale or cut out some colors. This is going to be a key to tuning this model, is figuring out the optimal normization for the images. Changing these sizes will require small changes to our model as well.
#
# We load a test and train set. We need to train and validate and they can't be the same. We also need to our labels for the data.

# %%
transform = transforms.Compose([transforms.Resize(256),
                                 transforms.ToTensor()])
training_dataset = datasets.ImageFolder('archive/Training', transform=transform)
testing_dataset = datasets.ImageFolder('archive/Testing', transform=transform)

# Class labels
classes = ('glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor')

# %% [markdown]
# We are going to load our training and test data and pick our batch size. Batch size is an important hyper parameter that will affect how fast our gradient descent converges or if it will at all. In our case this is 4 images at a time.

# %%
training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=4, shuffle=True)
validation_loader = torch.utils.data.DataLoader(testing_dataset, batch_size=4, shuffle=True)

# %% [markdown]
# The below code allows us to see the images from our training set and validate their labels.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Helper function for inline image display
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

dataiter = iter(training_loader)
images, labels = next(dataiter)

# Create a grid from the images and show them
img_grid = torchvision.utils.make_grid(images)
matplotlib_imshow(img_grid, one_channel=True)
print('  '.join(classes[labels[j]] for j in range(4)))
# Out:
# pituitary_tumor  pituitary_tumor  meningioma_tumor  pituitary_tumor

# %%
labels_map = {
    0: "Glioma",
    1: "Meningioma",
    2: "None",
    3: "Pituitary"
}
figure = plt.figure(figsize=(8, 8))
cols, rows = 3, 3
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(training_dataset), size=(1,)).item()
    img, label = training_dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(labels_map[label])
    plt.axis("off")
    plt.imshow(img.T, cmap="gray")
plt.show()
# Out:
# /var/folders/71/y1w_ptxd1m5b39p9kjdyys9h0000gn/T/ipykernel_94395/4028898404.py:15: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3701.)
#   plt.imshow(img.T, cmap="gray")

# %% [markdown]
# Ok we are going to seperate our images into batches and displays their labels.

# %%
for batch_number, (images, labels) in enumerate(training_loader):
    print(batch_number, labels)
# Out:
# 0 tensor([0, 1, 1, 3])
# 1 tensor([0, 1, 3, 0])
# 2 tensor([0, 1, 0, 0])
# 3 tensor([3, 0, 3, 0])
# 4 tensor([0, 3, 0, 3])
# 5 tensor([2, 0, 0, 1])
# 6 tensor([3, 3, 3, 0])
# 7 tensor([1, 2, 1, 2])
# 8 tensor([1, 3, 1, 3])
# 9 tensor([0, 1, 0, 2])
# 10 tensor([1, 0, 3, 2])
# 11 tensor([0, 1, 3, 3])
# 12 tensor([3, 1, 1, 0])
# 13 tensor([2, 3, 1, 0])
# 14 tensor([1, 0, 3, 0])
# 15 tensor([3, 2, 3, 1])
# 16 tensor([0, 1, 0, 3])
# 17 tensor([3, 1, 1, 3])
# 18 tensor([0, 2, 1, 2])
# 19 tensor([1, 3, 0, 3])
# 20 tensor([3, 1, 1, 0])
# 21 tensor([1, 0, 0, 0])
# 22 tensor([1, 3, 0, 2])
# 23 tensor([2, 3, 3, 1])
# 24 tensor([3, 1, 0, 1])
# 25 tensor([1, 3, 1, 1])
# 26 tensor([3, 1, 0, 3])
# 27 tensor([0, 3, 1, 2])
# 28 tensor([3, 1, 0, 3])
# 29 tensor([1, 0, 3, 0])
# 30 tensor([2, 3, 2, 0])
# 31 tensor([1, 3, 3, 2])
# 32 tensor([3, 0, 3, 3])
# 33 tensor([1, 2, 2, 2])
# 34 tensor([3, 2, 1, 3])
# 35 tensor([1, 2, 0, 2])
# 36 tensor([1, 3, 2, 2])
# 37 tensor([1, 1, 1, 0])
# 38 tensor([3, 1, 3, 1])
# 39 tensor([3, 1, 3, 3])
# 40 tensor([2, 0, 0, 3])
# 41 tensor([2, 0, 2, 2])
# 42 tensor([0, 3, 3, 2])
# 43 tensor([0, 2, 1, 3])
# 44 tensor([3, 1, 3, 2])
# 45 tensor([1, 3, 3, 0])
# 46 tensor([0, 0, 3, 0])
# 47 tensor([3, 1, 2, 2])
# 48 tensor([1, 3, 0, 0])
# 49 tensor([1, 3, 3, 1])
# 50 tensor([1, 1, 3, 1])
# 51 tensor([1, 2, 1, 1])
# 52 tensor([2, 0, 3, 0])
# 53 tensor([2, 0, 3, 2])
# 54 tensor([0, 2, 3, 3])
# 55 tensor([1, 0, 3, 0])
# 56 tensor([3, 1, 3, 0])
# 57 tensor([1, 0, 2, 1])
# 58 tensor([3, 0, 0, 2])
# 59 tensor([3, 1, 1, 3])
# 60 tensor([0, 0, 3, 1])
# 61 tensor([0, 0, 3, 0])
# 62 tensor([3, 1, 1, 3])
# 63 tensor([3, 0, 0, 2])
# 64 tensor([1, 0, 1, 0])
# 65 tensor([3, 3, 0, 3])
# 66 tensor([0, 1, 1, 2])
# 67 tensor([2, 1, 3, 3])
# 68 tensor([1, 1, 0, 2])
# 69 tensor([0, 3, 1, 1])
# 70 tensor([1, 1, 3, 2])
# 71 tensor([3, 1, 0, 2])
# 72 tensor([3, 1, 0, 1])
# 73 tensor([2, 3, 0, 0])
# 74 tensor([2, 0, 3, 3])
# 75 tensor([3, 0, 3, 1])
# 76 tensor([1, 3, 3, 1])
# 77 tensor([1, 1, 0, 3])
# 78 tensor([3, 3, 1, 0])
# 79 tensor([0, 3, 1, 1])
# 80 tensor([1, 0, 3, 3])
# 81 tensor([0, 2, 1, 3])
# 82 tensor([1, 1, 3, 2])
# 83 tensor([3, 3, 2, 3])
# 84 tensor([3, 3, 3, 3])
# 85 tensor([3, 0, 1, 1])
# 86 tensor([0, 1, 1, 3])
# 87 tensor([1, 3, 1, 1])
# 88 tensor([0, 3, 1, 0])
# 89 tensor([0, 1, 1, 0])
# 90 tensor([0, 1, 3, 3])
# 91 tensor([1, 3, 0, 3])
# 92 tensor([3, 1, 1, 0])
# 93 tensor([1, 3, 1, 3])
# 94 tensor([3, 1, 1, 3])
# 95 tensor([0, 0, 0, 3])
# 96 tensor([0, 3, 3, 1])
# 97 tensor([3, 3, 3, 0])
# 98 tensor([1, 1, 3, 3])
# 99 tensor([2, 1, 1, 3])
# 100 tensor([2, 3, 3, 3])
# 101 tensor([1, 1, 3, 3])
# 102 tensor([3, 0, 2, 3])
# 103 tensor([0, 1, 2, 2])
# 104 tensor([3, 3, 0, 0])
# 105 tensor([3, 0, 1, 1])
# 106 tensor([1, 0, 1, 1])
# 107 tensor([0, 0, 1, 0])
# 108 tensor([1, 3, 0, 0])
# 109 tensor([2, 2, 1, 1])
# 110 tensor([0, 0, 1, 1])
# 111 tensor([2, 0, 1, 0])
# 112 tensor([1, 1, 1, 0])
# 113 tensor([3, 2, 0, 2])
# 114 tensor([2, 0, 1, 3])
# 115 tensor([2, 0, 1, 3])
# 116 tensor([3, 1, 1, 1])
# 117 tensor([1, 1, 2, 3])
# 118 tensor([0, 0, 0, 3])
# 119 tensor([1, 2, 3, 3])
# 120 tensor([3, 0, 0, 0])
# 121 tensor([0, 2, 2, 3])
# 122 tensor([1, 0, 0, 0])
# 123 tensor([3, 1, 0, 2])
# 124 tensor([2, 2, 1, 1])
# 125 tensor([0, 1, 3, 1])
# 126 tensor([1, 0, 2, 1])
# 127 tensor([2, 1, 3, 2])
# 128 tensor([0, 3, 2, 1])
# 129 tensor([3, 0, 3, 2])
# 130 tensor([0, 0, 2, 1])
# 131 tensor([2, 0, 1, 0])
# 132 tensor([0, 1, 2, 2])
# 133 tensor([3, 1, 0, 0])
# 134 tensor([0, 3, 0, 3])
# 135 tensor([3, 3, 1, 0])
# 136 tensor([2, 1, 3, 1])
# 137 tensor([3, 1, 0, 1])
# 138 tensor([1, 0, 0, 3])
# 139 tensor([0, 0, 0, 1])
# 140 tensor([0, 2, 3, 2])
# 141 tensor([1, 1, 3, 1])
# 142 tensor([1, 0, 0, 2])
# 143 tensor([0, 3, 0, 3])
# 144 tensor([1, 1, 0, 1])
# 145 tensor([1, 1, 0, 1])
# 146 tensor([3, 0, 0, 3])
# 147 tensor([1, 0, 0, 1])
# 148 tensor([0, 3, 2, 2])
# 149 tensor([0, 3, 1, 0])
# 150 tensor([3, 2, 0, 0])
# 151 tensor([0, 3, 0, 0])
# 152 tensor([3, 1, 3, 0])
# 153 tensor([0, 3, 2, 0])
# 154 tensor([1, 3, 0, 0])
# 155 tensor([0, 1, 0, 3])
# 156 tensor([2, 1, 3, 0])
# 157 tensor([3, 2, 1, 1])
# 158 tensor([0, 3, 1, 2])
# 159 tensor([2, 1, 3, 0])
# 160 tensor([0, 1, 1, 3])
# 161 tensor([2, 3, 0, 1])
# 162 tensor([0, 0, 1, 3])
# 163 tensor([0, 0, 3, 1])
# 164 tensor([1, 3, 0, 1])
# 165 tensor([3, 3, 1, 2])
# 166 tensor([0, 0, 1, 1])
# 167 tensor([3, 2, 1, 2])
# 168 tensor([3, 3, 1, 1])
# 169 tensor([2, 1, 0, 0])
# 170 tensor([0, 0, 3, 2])
# 171 tensor([1, 3, 3, 0])
# 172 tensor([1, 0, 1, 0])
# 173 tensor([2, 0, 3, 0])
# 174 tensor([0, 0, 1, 3])
# 175 tensor([2, 3, 1, 1])
# 176 tensor([0, 2, 3, 1])
# 177 tensor([3, 3, 1, 0])
# 178 tensor([3, 0, 1, 3])
# 179 tensor([2, 1, 3, 0])
# 180 tensor([1, 3, 0, 1])
# 181 tensor([1, 0, 0, 3])
# 182 tensor([0, 3, 2, 3])
# 183 tensor([1, 1, 1, 3])
# 184 tensor([1, 1, 1, 2])
# 185 tensor([2, 0, 2, 0])
# 186 tensor([1, 1, 2, 0])
# 187 tensor([1, 1, 0, 0])
# 188 tensor([1, 3, 0, 2])
# 189 tensor([2, 0, 2, 0])
# 190 tensor([0, 3, 2, 1])
# 191 tensor([1, 0, 1, 0])
# 192 tensor([0, 2, 1, 1])
# 193 tensor([1, 2, 2, 3])
# 194 tensor([2, 0, 3, 3])
# 195 tensor([3, 1, 0, 3])
# 196 tensor([1, 3, 2, 2])
# 197 tensor([2, 2, 0, 1])
# 198 tensor([0, 1, 0, 1])
# 199 tensor([0, 1, 3, 0])
# 200 tensor([3, 3, 0, 1])
# 201 tensor([3, 3, 1, 0])
# 202 tensor([0, 3, 3, 2])
# 203 tensor([1, 0, 1, 2])
# 204 tensor([1, 0, 3, 3])
# 205 tensor([1, 3, 1, 2])
# 206 tensor([0, 2, 0, 0])
# 207 tensor([1, 3, 1, 3])
# 208 tensor([1, 0, 1, 3])
# 209 tensor([3, 0, 3, 2])
# 210 tensor([3, 0, 1, 2])
# 211 tensor([3, 2, 3, 0])
# 212 tensor([0, 2, 3, 2])
# 213 tensor([0, 0, 3, 1])
# 214 tensor([0, 2, 0, 0])
# 215 tensor([3, 0, 1, 3])
# 216 tensor([3, 1, 0, 1])
# 217 tensor([0, 3, 3, 0])
# 218 tensor([3, 2, 1, 3])
# 219 tensor([0, 0, 0, 1])
# 220 tensor([3, 1, 2, 3])
# 221 tensor([0, 1, 3, 1])
# 222 tensor([2, 3, 0, 1])
# 223 tensor([3, 3, 3, 1])
# 224 tensor([2, 1, 3, 2])
# 225 tensor([0, 3, 2, 3])
# 226 tensor([3, 1, 1, 0])
# 227 tensor([3, 0, 3, 1])
# 228 tensor([1, 2, 3, 1])
# 229 tensor([0, 1, 1, 1])
# 230 tensor([3, 1, 1, 1])
# 231 tensor([1, 1, 0, 1])
# 232 tensor([3, 0, 0, 3])
# 233 tensor([0, 0, 2, 1])
# 234 tensor([0, 1, 3, 1])
# 235 tensor([0, 0, 2, 3])
# 236 tensor([2, 3, 1, 1])
# 237 tensor([0, 2, 0, 3])
# 238 tensor([1, 1, 3, 2])
# 239 tensor([1, 0, 0, 0])
# 240 tensor([0, 0, 0, 3])
# 241 tensor([0, 0, 3, 1])
# 242 tensor([1, 2, 2, 3])
# 243 tensor([1, 0, 1, 0])
# 244 tensor([2, 2, 0, 3])
# 245 tensor([0, 1, 3, 0])
# 246 tensor([3, 1, 3, 0])
# 247 tensor([3, 2, 1, 1])
# 248 tensor([1, 1, 0, 0])
# 249 tensor([1, 1, 0, 0])
# 250 tensor([0, 0, 3, 2])
# 251 tensor([1, 0, 1, 2])
# 252 tensor([3, 3, 3, 1])
# 253 tensor([3, 1, 1, 1])
# 254 tensor([0, 2, 3, 1])
# 255 tensor([1, 1, 0, 0])
# 256 tensor([0, 3, 1, 0])
# 257 tensor([1, 2, 1, 0])
# 258 tensor([0, 3, 1, 1])
# 259 tensor([1, 0, 1, 3])
# 260 tensor([0, 1, 2, 3])
# 261 tensor([3, 0, 3, 1])
# 262 tensor([3, 3, 2, 0])
# 263 tensor([3, 0, 0, 1])
# 264 tensor([2, 1, 1, 3])
# 265 tensor([1, 0, 3, 0])
# 266 tensor([3, 3, 3, 1])
# 267 tensor([2, 1, 0, 0])
# 268 tensor([3, 2, 2, 0])
# 269 tensor([1, 3, 3, 3])
# 270 tensor([3, 3, 1, 3])
# 271 tensor([0, 1, 0, 0])
# 272 tensor([2, 1, 0, 0])
# 273 tensor([0, 0, 0, 0])
# 274 tensor([1, 0, 3, 0])
# 275 tensor([1, 1, 3, 1])
# 276 tensor([0, 0, 1, 0])
# 277 tensor([3, 1, 1, 3])
# 278 tensor([0, 1, 3, 3])
# 279 tensor([0, 3, 0, 0])
# 280 tensor([2, 3, 2, 1])
# 281 tensor([0, 1, 0, 1])
# 282 tensor([0, 1, 0, 1])
# 283 tensor([0, 0, 2, 0])
# 284 tensor([3, 3, 1, 0])
# 285 tensor([0, 3, 1, 3])
# 286 tensor([1, 2, 0, 1])
# 287 tensor([1, 2, 0, 3])
# 288 tensor([3, 1, 3, 1])
# 289 tensor([2, 3, 3, 1])
# 290 tensor([3, 3, 1, 1])
# 291 tensor([2, 0, 3, 1])
# 292 tensor([1, 1, 0, 1])
# 293 tensor([1, 0, 0, 3])
# 294 tensor([0, 2, 0, 3])
# 295 tensor([0, 0, 0, 0])
# 296 tensor([1, 2, 3, 3])
# 297 tensor([3, 1, 0, 0])
# 298 tensor([3, 0, 1, 1])
# 299 tensor([3, 3, 0, 1])
# 300 tensor([1, 1, 3, 3])
# 301 tensor([0, 2, 1, 0])
# 302 tensor([3, 0, 1, 2])
# 303 tensor([1, 2, 1, 2])
# 304 tensor([0, 3, 0, 3])
# 305 tensor([0, 1, 0, 3])
# 306 tensor([2, 3, 1, 1])
# 307 tensor([1, 1, 0, 0])
# 308 tensor([3, 3, 1, 3])
# 309 tensor([1, 2, 1, 0])
# 310 tensor([0, 3, 2, 1])
# 311 tensor([1, 2, 0, 3])
# 312 tensor([0, 1, 1, 2])
# 313 tensor([2, 1, 0, 3])
# 314 tensor([3, 0, 3, 3])
# 315 tensor([3, 3, 0, 0])
# 316 tensor([3, 3, 3, 3])
# 317 tensor([3, 2, 0, 1])
# 318 tensor([1, 0, 0, 1])
# 319 tensor([0, 2, 0, 1])
# 320 tensor([3, 1, 1, 0])
# 321 tensor([1, 1, 0, 3])
# 322 tensor([3, 2, 1, 0])
# 323 tensor([1, 2, 3, 0])
# 324 tensor([3, 3, 3, 2])
# 325 tensor([3, 3, 3, 1])
# 326 tensor([0, 3, 2, 1])
# 327 tensor([1, 2, 0, 3])
# 328 tensor([1, 2, 0, 2])
# 329 tensor([3, 2, 1, 0])
# 330 tensor([0, 1, 0, 1])
# 331 tensor([3, 0, 2, 3])
# 332 tensor([2, 1, 0, 0])
# 333 tensor([3, 3, 3, 1])
# 334 tensor([2, 0, 3, 1])
# 335 tensor([1, 1, 1, 1])
# 336 tensor([1, 1, 0, 2])
# 337 tensor([3, 1, 2, 0])
# 338 tensor([3, 0, 1, 2])
# 339 tensor([3, 2, 1, 3])
# 340 tensor([2, 3, 2, 0])
# 341 tensor([1, 3, 1, 3])
# 342 tensor([0, 0, 1, 2])
# 343 tensor([0, 3, 1, 0])
# 344 tensor([3, 0, 0, 0])
# 345 tensor([1, 3, 0, 0])
# 346 tensor([0, 0, 0, 2])
# 347 tensor([0, 1, 2, 0])
# 348 tensor([0, 3, 3, 0])
# 349 tensor([1, 1, 2, 1])
# 350 tensor([1, 0, 3, 0])
# 351 tensor([0, 2, 2, 0])
# 352 tensor([2, 1, 1, 1])
# 353 tensor([0, 3, 2, 0])
# 354 tensor([0, 2, 3, 3])
# 355 tensor([0, 3, 0, 1])
# 356 tensor([1, 0, 3, 3])
# 357 tensor([3, 0, 0, 3])
# 358 tensor([3, 1, 1, 0])
# 359 tensor([0, 3, 0, 0])
# 360 tensor([0, 0, 0, 2])
# 361 tensor([0, 3, 3, 3])
# 362 tensor([3, 3, 1, 1])
# 363 tensor([0, 1, 1, 2])
# 364 tensor([0, 0, 3, 0])
# 365 tensor([1, 0, 0, 0])
# 366 tensor([2, 2, 0, 0])
# 367 tensor([1, 2, 3, 1])
# 368 tensor([1, 0, 0, 3])
# 369 tensor([1, 0, 0, 3])
# 370 tensor([0, 1, 0, 3])
# 371 tensor([1, 3, 1, 1])
# 372 tensor([1, 2, 1, 0])
# 373 tensor([1, 1, 1, 0])
# 374 tensor([3, 3, 2, 3])
# 375 tensor([2, 2, 3, 2])
# 376 tensor([3, 1, 0, 1])
# 377 tensor([0, 1, 0, 3])
# 378 tensor([2, 1, 0, 3])
# 379 tensor([1, 2, 3, 1])
# 380 tensor([2, 0, 1, 1])
# 381 tensor([1, 3, 3, 1])
# 382 tensor([3, 1, 3, 3])
# 383 tensor([3, 0, 1, 0])
# 384 tensor([0, 0, 3, 3])
# 385 tensor([0, 0, 1, 0])
# 386 tensor([0, 3, 3, 3])
# 387 tensor([1, 2, 3, 0])
# 388 tensor([3, 0, 1, 3])
# 389 tensor([1, 1, 1, 3])
# 390 tensor([3, 3, 3, 0])
# 391 tensor([3, 0, 0, 1])
# 392 tensor([0, 1, 0, 3])
# 393 tensor([3, 1, 0, 2])
# 394 tensor([1, 1, 3, 0])
# 395 tensor([0, 3, 1, 3])
# 396 tensor([2, 1, 1, 3])
# 397 tensor([1, 1, 1, 2])
# 398 tensor([1, 3, 3, 2])
# 399 tensor([3, 3, 0, 3])
# 400 tensor([0, 0, 1, 0])
# 401 tensor([3, 0, 2, 0])
# 402 tensor([0, 0, 1, 0])
# 403 tensor([3, 0, 0, 3])
# 404 tensor([3, 3, 2, 2])
# 405 tensor([1, 3, 2, 1])
# 406 tensor([2, 2, 3, 2])
# 407 tensor([3, 1, 1, 3])
# 408 tensor([3, 0, 1, 2])
# 409 tensor([0, 2, 0, 3])
# 410 tensor([0, 3, 0, 0])
# 411 tensor([0, 0, 0, 0])
# 412 tensor([1, 3, 0, 1])
# 413 tensor([1, 0, 2, 3])
# 414 tensor([1, 3, 1, 1])
# 415 tensor([1, 3, 3, 1])
# 416 tensor([3, 2, 3, 1])
# 417 tensor([0, 3, 0, 1])
# 418 tensor([3, 2, 0, 3])
# 419 tensor([3, 0, 0, 3])
# 420 tensor([3, 3, 0, 3])
# 421 tensor([0, 0, 2, 0])
# 422 tensor([2, 0, 1, 3])
# 423 tensor([1, 0, 3, 2])
# 424 tensor([3, 0, 0, 1])
# 425 tensor([1, 3, 0, 3])
# 426 tensor([1, 1, 0, 0])
# 427 tensor([1, 3, 1, 0])
# 428 tensor([1, 1, 2, 1])
# 429 tensor([0, 0, 1, 3])
# 430 tensor([3, 0, 1, 3])
# 431 tensor([0, 1, 1, 0])
# 432 tensor([0, 1, 0, 1])
# 433 tensor([2, 1, 3, 0])
# 434 tensor([1, 3, 3, 3])
# 435 tensor([2, 1, 1, 2])
# 436 tensor([0, 0, 3, 1])
# 437 tensor([1, 0, 3, 0])
# 438 tensor([3, 0, 1, 1])
# 439 tensor([3, 1, 1, 0])
# 440 tensor([3, 0, 3, 3])
# 441 tensor([3, 3, 3, 1])
# 442 tensor([1, 1, 3, 0])
# 443 tensor([1, 0, 3, 0])
# 444 tensor([1, 3, 3, 2])
# 445 tensor([3, 1, 2, 0])
# 446 tensor([0, 1, 0, 1])
# 447 tensor([2, 0, 3, 0])
# 448 tensor([1, 3, 3, 1])
# 449 tensor([2, 0, 0, 2])
# 450 tensor([1, 1, 0, 3])
# 451 tensor([3, 3, 3, 1])
# 452 tensor([1, 3, 2, 3])
# 453 tensor([1, 2, 3, 0])
# 454 tensor([0, 3, 1, 3])
# 455 tensor([2, 1, 3, 0])
# 456 tensor([1, 0, 2, 1])
# 457 tensor([1, 3, 3, 0])
# 458 tensor([1, 3, 3, 1])
# 459 tensor([0, 2, 0, 2])
# 460 tensor([3, 0, 1, 2])
# 461 tensor([1, 2, 2, 0])
# 462 tensor([2, 1, 3, 0])
# 463 tensor([0, 3, 1, 2])
# 464 tensor([3, 0, 0, 1])
# 465 tensor([2, 1, 3, 1])
# 466 tensor([3, 3, 0, 1])
# 467 tensor([0, 1, 1, 1])
# 468 tensor([1, 2, 2, 0])
# 469 tensor([1, 1, 3, 0])
# 470 tensor([1, 1, 3, 0])
# 471 tensor([1, 3, 3, 2])
# 472 tensor([3, 0, 3, 0])
# 473 tensor([1, 1, 0, 1])
# 474 tensor([0, 1, 2, 0])
# 475 tensor([3, 3, 0, 3])
# 476 tensor([3, 2, 0, 3])
# 477 tensor([0, 3, 3, 3])
# 478 tensor([3, 3, 1, 1])
# 479 tensor([2, 3, 0, 1])
# 480 tensor([1, 3, 0, 3])
# 481 tensor([2, 0, 1, 1])
# 482 tensor([3, 2, 0, 3])
# 483 tensor([1, 2, 0, 1])
# 484 tensor([0, 3, 0, 3])
# 485 tensor([1, 0, 2, 3])
# 486 tensor([3, 0, 1, 1])
# 487 tensor([0, 1, 1, 2])
# 488 tensor([3, 3, 0, 1])
# 489 tensor([0, 1, 3, 1])
# 490 tensor([0, 2, 3, 2])
# 491 tensor([0, 0, 1, 1])
# 492 tensor([3, 3, 1, 2])
# 493 tensor([1, 1, 1, 3])
# 494 tensor([2, 1, 2, 0])
# 495 tensor([0, 3, 3, 1])
# 496 tensor([1, 0, 2, 1])
# 497 tensor([1, 1, 0, 0])
# 498 tensor([0, 1, 0, 3])
# 499 tensor([3, 2, 1, 2])
# 500 tensor([3, 0, 1, 0])
# 501 tensor([3, 1, 3, 2])
# 502 tensor([0, 3, 3, 1])
# 503 tensor([2, 0, 0, 2])
# 504 tensor([1, 0, 3, 0])
# 505 tensor([2, 3, 1, 0])
# 506 tensor([3, 0, 0, 3])
# 507 tensor([0, 3, 1, 1])
# 508 tensor([2, 1, 3, 1])
# 509 tensor([1, 1, 1, 0])
# 510 tensor([1, 3, 0, 3])
# 511 tensor([3, 0, 1, 1])
# 512 tensor([0, 0, 0, 2])
# 513 tensor([2, 2, 2, 0])
# 514 tensor([0, 3, 0, 1])
# 515 tensor([0, 1, 3, 1])
# 516 tensor([0, 2, 1, 3])
# 517 tensor([2, 3, 3, 3])
# 518 tensor([1, 3, 3, 1])
# 519 tensor([3, 1, 0, 0])
# 520 tensor([0, 2, 3, 3])
# 521 tensor([3, 1, 0, 3])
# 522 tensor([0, 1, 0, 0])
# 523 tensor([0, 1, 1, 3])
# 524 tensor([3, 1, 1, 0])
# 525 tensor([1, 3, 1, 3])
# 526 tensor([1, 3, 2, 0])
# 527 tensor([2, 0, 3, 2])
# 528 tensor([0, 2, 0, 2])
# 529 tensor([2, 3, 3, 0])
# 530 tensor([1, 1, 0, 3])
# 531 tensor([1, 0, 3, 3])
# 532 tensor([2, 0, 3, 0])
# 533 tensor([3, 3, 1, 0])
# 534 tensor([3, 3, 0, 0])
# 535 tensor([3, 3, 1, 3])
# 536 tensor([0, 0, 0, 2])
# 537 tensor([0, 0, 2, 3])
# 538 tensor([0, 3, 2, 0])
# 539 tensor([1, 2, 1, 1])
# 540 tensor([1, 3, 3, 0])
# 541 tensor([1, 1, 1, 0])
# 542 tensor([3, 0, 0, 0])
# 543 tensor([1, 3, 3, 3])
# 544 tensor([3, 0, 1, 1])
# 545 tensor([1, 0, 0, 1])
# 546 tensor([2, 0, 1, 2])
# 547 tensor([0, 0, 1, 1])
# 548 tensor([3, 3, 1, 3])
# 549 tensor([1, 1, 3, 2])
# 550 tensor([3, 3, 0, 0])
# 551 tensor([0, 2, 0, 0])
# 552 tensor([1, 1, 1, 3])
# 553 tensor([2, 0, 0, 3])
# 554 tensor([0, 3, 1, 3])
# 555 tensor([0, 2, 2, 0])
# 556 tensor([0, 2, 3, 2])
# 557 tensor([2, 1, 0, 1])
# 558 tensor([2, 1, 1, 3])
# 559 tensor([1, 1, 2, 2])
# 560 tensor([1, 3, 2, 2])
# 561 tensor([0, 3, 1, 0])
# 562 tensor([0, 2, 3, 2])
# 563 tensor([0, 3, 1, 0])
# 564 tensor([0, 0, 1, 3])
# 565 tensor([1, 2, 3, 2])
# 566 tensor([0, 0, 0, 1])
# 567 tensor([1, 0, 0, 2])
# 568 tensor([0, 0, 0, 1])
# 569 tensor([3, 3, 0, 0])
# 570 tensor([3, 1, 1, 2])
# 571 tensor([0, 0, 1, 3])
# 572 tensor([0, 3, 2, 3])
# 573 tensor([1, 0, 3, 2])
# 574 tensor([0, 3, 0, 3])
# 575 tensor([1, 0, 3, 1])
# 576 tensor([0, 2, 3, 3])
# 577 tensor([3, 3, 1, 3])
# 578 tensor([3, 1, 1, 2])
# 579 tensor([1, 0, 1, 3])
# 580 tensor([1, 3, 1, 1])
# 581 tensor([0, 0, 3, 3])
# 582 tensor([1, 3, 1, 0])
# 583 tensor([3, 0, 0, 3])
# 584 tensor([3, 3, 3, 1])
# 585 tensor([1, 3, 1, 2])
# 586 tensor([3, 0, 0, 0])
# 587 tensor([0, 0, 2, 0])
# 588 tensor([1, 2, 3, 1])
# 589 tensor([2, 3, 1, 0])
# 590 tensor([1, 2, 0, 1])
# 591 tensor([1, 0, 3, 0])
# 592 tensor([3, 2, 3, 3])
# 593 tensor([1, 0, 1, 0])
# 594 tensor([3, 2, 1, 0])
# 595 tensor([1, 0, 2, 3])
# 596 tensor([0, 1, 3, 1])
# 597 tensor([2, 0, 3, 3])
# 598 tensor([2, 1, 2, 1])
# 599 tensor([3, 0, 3, 3])
# 600 tensor([0, 0, 3, 2])
# 601 tensor([3, 3, 3, 2])
# 602 tensor([2, 3, 3, 2])
# 603 tensor([0, 0, 1, 0])
# 604 tensor([1, 0, 3, 0])
# 605 tensor([3, 2, 2, 3])
# 606 tensor([3, 1, 3, 0])
# 607 tensor([0, 1, 3, 1])
# 608 tensor([2, 3, 1, 3])
# 609 tensor([0, 1, 0, 0])
# 610 tensor([1, 1, 1, 1])
# 611 tensor([0, 1, 3, 1])
# 612 tensor([1, 0, 3, 1])
# 613 tensor([2, 3, 1, 1])
# 614 tensor([3, 0, 1, 1])
# 615 tensor([0, 1, 0, 3])
# 616 tensor([3, 3, 3, 3])
# 617 tensor([3, 3, 3, 3])
# 618 tensor([3, 0, 3, 1])
# 619 tensor([3, 2, 1, 3])
# 620 tensor([0, 2, 1, 1])
# 621 tensor([2, 1, 3, 3])
# 622 tensor([1, 3, 2, 3])
# 623 tensor([3, 0, 0, 3])
# 624 tensor([0, 0, 3, 0])
# 625 tensor([1, 3, 1, 3])
# 626 tensor([3, 1, 1, 1])
# 627 tensor([0, 3, 3, 1])
# 628 tensor([2, 0, 3, 3])
# 629 tensor([0, 0, 3, 0])
# 630 tensor([2, 1, 0, 3])
# 631 tensor([3, 1, 3, 0])
# 632 tensor([1, 3, 3, 0])
# 633 tensor([3, 2, 0, 2])
# 634 tensor([0, 1, 3, 0])
# 635 tensor([3, 2, 2, 1])
# 636 tensor([0, 2, 3, 3])
# 637 tensor([3, 3, 0, 2])
# 638 tensor([0, 1, 1, 2])
# 639 tensor([0, 3, 2, 1])
# 640 tensor([3, 3, 1, 1])
# 641 tensor([2, 0, 0, 3])
# 642 tensor([1, 0, 0, 1])
# 643 tensor([0, 0, 2, 3])
# 644 tensor([3, 2, 2, 1])
# 645 tensor([0, 0, 3, 1])
# 646 tensor([0, 3, 1, 0])
# 647 tensor([3, 2, 1, 1])
# 648 tensor([2, 0, 0, 2])
# 649 tensor([0, 2, 0, 1])
# 650 tensor([0, 3, 0, 3])
# 651 tensor([3, 3, 3, 3])
# 652 tensor([3, 0, 3, 3])
# 653 tensor([1, 1, 3, 0])
# 654 tensor([2, 3, 0, 1])
# 655 tensor([1, 3, 3, 3])
# 656 tensor([1, 1, 0, 0])
# 657 tensor([3, 1, 1, 0])
# 658 tensor([0, 1, 1, 0])
# 659 tensor([2, 0, 0, 2])
# 660 tensor([0, 1, 1, 0])
# 661 tensor([2, 1, 0, 1])
# 662 tensor([0, 3, 2, 2])
# 663 tensor([3, 3, 3, 1])
# 664 tensor([1, 0, 0, 3])
# 665 tensor([2, 1, 3, 3])
# 666 tensor([2, 2, 3, 0])
# 667 tensor([1, 1, 1, 0])
# 668 tensor([2, 0, 3, 1])
# 669 tensor([3, 0, 0, 1])
# 670 tensor([3, 3, 1, 0])
# 671 tensor([3, 3, 1, 1])
# 672 tensor([1, 1, 1, 0])
# 673 tensor([1, 3, 3, 0])
# 674 tensor([1, 1, 1, 1])
# 675 tensor([2, 1, 0, 0])
# 676 tensor([2, 1, 3, 1])
# 677 tensor([0, 0, 1, 1])
# 678 tensor([0, 0, 3, 3])
# 679 tensor([0, 1, 3, 2])
# 680 tensor([0, 1, 1, 3])
# 681 tensor([0, 1, 3, 3])
# 682 tensor([3, 1, 1, 3])
# 683 tensor([3, 3, 1, 2])
# 684 tensor([1, 3, 1, 1])
# 685 tensor([1, 1, 0, 3])
# 686 tensor([1, 3, 0, 0])
# 687 tensor([1, 3, 3, 1])
# 688 tensor([3, 2, 1, 1])
# 689 tensor([0, 0, 1, 3])
# 690 tensor([3, 2, 0, 3])
# 691 tensor([3, 2, 0, 3])
# 692 tensor([1, 1, 3, 0])
# 693 tensor([1, 0, 3, 3])
# 694 tensor([3, 2, 2, 3])
# 695 tensor([1, 1, 3, 0])
# 696 tensor([3, 1, 1, 3])
# 697 tensor([3, 0, 2, 3])
# 698 tensor([2, 0, 3, 0])
# 699 tensor([3, 0, 0, 1])
# 700 tensor([2, 0, 2, 0])
# 701 tensor([1, 0, 1, 0])
# 702 tensor([2, 1, 3, 0])
# 703 tensor([1, 1, 1, 1])
# 704 tensor([0, 3, 0, 3])
# 705 tensor([2, 2, 1, 1])
# 706 tensor([0, 0, 1, 3])
# 707 tensor([3, 2, 3, 3])
# 708 tensor([0, 0, 2, 0])
# 709 tensor([1, 0, 0, 1])
# 710 tensor([3, 2, 3, 0])
# 711 tensor([3, 1, 3, 3])
# 712 tensor([0, 3, 3, 3])
# 713 tensor([0, 2, 0, 0])
# 714 tensor([0, 0, 2, 1])
# 715 tensor([3, 3, 1, 3])
# 716 tensor([0, 0, 1, 1])
# 717 tensor([1, 0])

# %% [markdown]
# This chooses to either use CUDA which is for nvidia GPUs or your local devices. My macbook air was able to run this model and training with it's built in GPU but image size and batch size can easily run this thing out of memory.

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using mps device

# %% [markdown]
# This is our first model we developed just to test it all out. It took 128x128 pixels however and won't run with the above transformations.
#
# This produced 68% accuracy with 20 epochs of training and a .001 lr with momentum of .9 and SGD optimizer.

# %%
import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class TumorClassifier(nn.Module):
    def __init__(self):
        super(TumorClassifier, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 3)
        self.conv2 = nn.Conv2d(6, 16, 3)
        self.conv3 = nn.Conv2d(16, 64, 3)
        self.pool = nn.MaxPool2d(2, 2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(4*56*56,120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.flatten(x)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


model = TumorClassifier()

# %% [markdown]
# Below is the actual CNN - the neural network. I'm not going to explain how all these numbers work, I'm still learning exactly when and how to tune them myself. Ultimately these deterime the amount of input and output channels and the amount of layers in between where learning occurs. All of the numbers must match up mathmatelically for a functioning neural network. For example changing the batch and/or image size would affect all of this.
#
# This CNN model produces ~73% accuracy with 20 epochs of training and a .001 lr with momentum of .9 and SGD optimizer.

# %%
import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class TumorClassifier(nn.Module):
    def __init__(self):
        super(TumorClassifier, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv6 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv7 = nn.Conv2d(256, 256, 3, padding=1)
        self.conv8 = nn.Conv2d(256, 256, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv9 = nn.Conv2d(256, 512, 3, padding=1)
        self.conv10 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv11 = nn.Conv2d(512, 512, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv12 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv13 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv14 = nn.Conv2d(512, 512, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(512 * 7 * 7,4096)
        self.fc2 = nn.Linear(4096, 4096)
        self.dropout = nn.Dropout()
        self.fc3 = nn.Linear(4096, 4)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        # x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.pool(x)
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.relu(self.conv8(x))
        x = self.pool(x)
        x = F.relu(self.conv9(x))
        x = F.relu(self.conv10(x))
        x = F.relu(self.conv11(x))
        x = self.pool(x)
        x = F.relu(self.conv12(x))
        x = F.relu(self.conv13(x))
        x = F.relu(self.conv14(x))
        x = self.pool(x)
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x


model = TumorClassifier()

# %% [markdown]
# This is an experimental model based on VGG19. It's not working as well as the other models however it required a much large fully connected layer we couldn't run on our computers.

# %%
import torch.nn as nn
import torch.nn.functional as F

# PyTorch models inherit from torch.nn.Module
class TumorClassifier(nn.Module):
    def __init__(self):
        super(TumorClassifier, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 64, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
       # self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv6 = nn.Conv2d(128, 256, 3, padding=1)
        self.conv7 = nn.Conv2d(256, 256, 3, padding=1)
        self.conv8 = nn.Conv2d(256, 256, 3, padding=1)
        self.conv9 = nn.Conv2d(256, 256, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv10 = nn.Conv2d(256, 512, 3, padding=1)
        self.conv11 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv12 = nn.Conv2d(512, 512, 3, padding=1)
        self.conv13 = nn.Conv2d(512, 512, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(4*18432,2048)
        self.fc2 = nn.Linear(2048, 2048)
        self.fc3 = nn.Linear(2048, 4)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        # x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        x = F.relu(self.conv4(x))
        x = F.relu(self.conv5(x))
        x = self.pool(x)
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = F.relu(self.conv8(x))
        x = F.relu(self.conv9(x))
        x = self.pool(x)
        x = F.relu(self.conv10(x))
        x = F.relu(self.conv11(x))
        x = F.relu(self.conv12(x))
        x = F.relu(self.conv13(x))
        x = self.pool(x)
        x = self.flatten(x)
        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = x.dropout()
        x = self.fc3(x)
        return x


model = TumorClassifier()

# %% [markdown]
# Setting up our loss function and confirming it works on some dummy data.

# %%
loss_fn = torch.nn.CrossEntropyLoss()

# NB: Loss functions expect data in batches, so we're creating batches of 4
# Represents the model's confidence in each of the 10 classes for a given input
dummy_outputs = torch.rand(2, 4)
# Represents the correct class among the 10 being tested
dummy_labels = torch.tensor([1, 3])

print(dummy_outputs)
print(dummy_labels)

loss = loss_fn(dummy_outputs, dummy_labels)
print('Total loss for this batch: {}'.format(loss.item()))
# Out:
# tensor([[0.8169, 0.0148, 0.9433, 0.2996],
#         [0.3600, 0.3124, 0.1758, 0.5385]])
# tensor([1, 3])
# Total loss for this batch: 1.5808119773864746

# %% [markdown]
# Time to train! This is programmed to train for 10 epochs (cycles) and print out every 200 batches how our loss is perfomring. It should, for the most part continue to decrease. The lower the better, but once it starts to increase your going in the wrong direction and have put to many cycles in.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)
scheduler = StepLR(optimizer, step_size=5, gamma=0.1)  # Decay LR every 5 epochs by a factor of 0.1
for epoch in range(50):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(training_loader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i % 200 == 199:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 200:.3f}')
            running_loss = 0.0
    # Adjust learning rate
   # scheduler.step()

print('Finished Training')
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
model_path = 'model_{}'.format(timestamp)
torch.save(model.state_dict(), model_path)
# Out:
# [1,   200] loss: 1.345
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 16
#      14 outputs = model(inputs)
#      15 loss = loss_fn(outputs, labels)
# ---> 16 loss.backward()
#      17 optimizer.step()
#      19 # print statistics
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Assuming model, loss_fn, training_loader, and validation_loader are already defined
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
scheduler = StepLR(optimizer, step_size=5, gamma=0.1)  # Decay LR every 5 epochs by a factor of 0.1

best_val_loss = float('inf')  # To track the best validation loss
overfitting_threshold = 3  # Number of epochs to wait before assuming overfitting
epochs_since_improvement = 0  # Counter for epochs without validation improvement



for epoch in range(15):  # loop over the dataset multiple times
    model.train()  # Set model to training mode
    running_loss = 0.0

    for i, data in enumerate(training_loader, 0):
        # Get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward + backward + optimize
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()

        # Accumulate loss for reporting
        running_loss += loss.item()
        if i % 200 == 199:  # Print every 200 mini-batches
            print(f'[Epoch {epoch + 1}, Batch {i + 1}] Loss: {running_loss / 200:.4f}')
            running_loss = 0.0

    # Adjust learning rate
    scheduler.step()

    # Validation phase
    model.eval()  # Set model to evaluation mode
    val_loss = 0.0
    with torch.no_grad():
        for val_data in validation_loader:
            val_inputs, val_labels = val_data
            val_outputs = model(val_inputs)
            val_loss += loss_fn(val_outputs, val_labels).item()
    val_loss /= len(validation_loader)  # Average validation loss
    print(f'Epoch {epoch + 1} Validation Loss: {val_loss:.4f}')

    # Check for overfitting
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        epochs_since_improvement = 0
        # Save the best model
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        model_path = f'model_best_{timestamp}.pth'
        torch.save(model.state_dict(), model_path)
        print(f'Validation loss improved. Model saved to {model_path}')
    else:
        epochs_since_improvement += 1
        print(f'No improvement in validation loss for {epochs_since_improvement} epoch(s).')

    # Early stopping condition
    if epochs_since_improvement >= overfitting_threshold:
        print("Stopping early due to no improvement in validation loss.")
        break

print('Training Finished.')

# %% [markdown]
# Now that we have our model trained and saved, we need to see how it performs.
#
# Just like we did with the training data, we are going to do with the validation data. Make sure the images and lables are correct.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Helper function for inline image display
def matplotlib_imshow(img, one_channel=False):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg, cmap="Greys")
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

dataiter = iter(validation_loader)
images, labels = next(dataiter)

# Create a grid from the images and show them
img_grid = torchvision.utils.make_grid(images)
matplotlib_imshow(img_grid, one_channel=True)
print('  '.join(classes[labels[j]] for j in range(4)))
# Out:
# no_tumor  pituitary_tumor  meningioma_tumor  no_tumor

# %% [markdown]
# Now the fun part, now we load our network and model and we run a prediction on this same data. Amazingly, they are all the same 4/4. The model works!!

# %%
net = TumorClassifier()
net.load_state_dict(torch.load(model_path, weights_only=True))
outputs = net(images)
_, predicted = torch.max(outputs, 1)
print('Predicted: ', ' '.join(f'{classes[predicted[j]]:5s}'
                              for j in range(4)))
# Out:
# Predicted:  no_tumor pituitary_tumor meningioma_tumor no_tumor

# %% [markdown]
# How good is the model overall? We're going to test it on our entire validation set and see!
#
# Currently, first run, no tuning, just messing around, it's at 68%... pure chance is 25%, so doing pretty good! We can probably make it much better. More to come.

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in validation_loader:
        images, labels = data
        # calculate outputs by running images through the network
        outputs = net(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the test images: {100 * correct // total} %')
# Out:
# Accuracy of the network on the test images: 71 %
